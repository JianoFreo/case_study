# %% [markdown]
# # 01_generate_data.ipynb
# Generate realistic synthetic Philippine-style datasets for the BI project. This notebook can run independently from top to bottom.

# %%
from pathlib import Path
import sys
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from faker import Faker
warnings.filterwarnings('ignore')
BASE_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
RAW_DATA_DIR = BASE_DIR / 'data' / 'raw'
PROCESSED_DATA_DIR = BASE_DIR / 'data' / 'processed'
GENERATED_DATA_DIR = BASE_DIR / 'data' / 'generated'
RAW_DATA_DIR.mkdir(parents=True, exist_ok=True)
PROCESSED_DATA_DIR.mkdir(parents=True, exist_ok=True)
GENERATED_DATA_DIR.mkdir(parents=True, exist_ok=True)
if str(BASE_DIR) not in sys.path:
    sys.path.insert(0, str(BASE_DIR))
import src.generate_data as generate_data
print('Setup complete')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 21
#      19 if str(BASE_DIR) not in sys.path:
#      20     sys.path.insert(0, str(BASE_DIR))
# ---> 21 import src.generate_data as generate_data
#      22 print('Setup complete')
#
# ModuleNotFoundError: No module named 'src'

# %%
# Generate all datasets if they do not already exist
generated_paths = generate_data.generate_all(n_each=1000, out_dir=GENERATED_DATA_DIR)
generated_paths
# Out:
# {'barangay_census.csv': 'C:\\Users\\User\\Desktop\\case_study\\google-bi-dashboard-project\\data\\generated\\barangay_census.csv',
#  'sales_orders.csv': 'C:\\Users\\User\\Desktop\\case_study\\google-bi-dashboard-project\\data\\generated\\sales_orders.csv',
#  'medical_records.csv': 'C:\\Users\\User\\Desktop\\case_study\\google-bi-dashboard-project\\data\\generated\\medical_records.csv',
#  'school_enrollment.csv': 'C:\\Users\\User\\Desktop\\case_study\\google-bi-dashboard-project\\data\\generated\\school_enrollment.csv'}

# %%
# List generated files
csv_files = sorted(GENERATED_DATA_DIR.glob('*.csv'))
[p.name for p in csv_files]
# Out:
# ['barangay_census.csv',
#  'medical_records.csv',
#  'sales_orders.csv',
#  'school_enrollment.csv']

# %%
# Preview the first few rows of each dataset
for csv_path in csv_files:
    print(f'\n=== {csv_path.name} ===')
    preview_df = pd.read_csv(csv_path)
    display(preview_df.head())
    print('Shape:', preview_df.shape)
# Out:
# === barangay_census.csv ===
#    record_id   barangay          city  households  population  median_income  \
# 0        384  Magsaysay  Bacolod City       189.0       945.0        17343.0
# 1        776  Sta. Cruz         Pasig       193.0       772.0         9131.0
# 2        792     Mabini    Davao City       204.0       816.0        30658.0
# 3        132  Bayanihan     Cebu City       226.0      1130.0        21480.0
# 4        465  Bayanihan    Davao City       213.0       639.0        19572.0
#
#   collection_date
# 0      2025-06-16
# 1      2024-10-27
# 2      2026-04-10
# 3      2025-08-09
# 4      2025-07-01
# Shape: (1020, 7)
#
# === medical_records.csv ===
#      visit_id  visit_date      patient_name   age     sex    barangay  \
# 0  MED-200383  2025-03-27     Adam Thompson  67.0    Male   Bayanihan
# 1  MED-200775  2024-10-06     Melissa Perez  27.0  Female   Magsaysay
# 2  MED-200791  2025-08-03  Jacqueline Vance  47.0  Female  San Miguel
# 3  MED-200131  2025-04-30    Angela Edwards  50.0    Male   Sta. Cruz
# 4  MED-200464  2025-12-15     Diane Stewart  20.0    Male    Maligaya
#
#    diagnosis  temperature_c  cholesterol_mgdl  weight_kg
# 0     Asthma           38.2             158.0       60.7
# 1      Fever           37.0             179.0       65.7
# 2      Fever           37.3             188.0       89.3
# 3      Fever           37.3             128.0       72.7
# 4  Infection           36.8             159.0       75.2
# Shape: (1020, 10)
#
# === sales_orders.csv ===
#     order_id  order_date      customer_name       barangay          product  \
# 0  SO-100383  2026-05-24       Elijah Young       Maligaya             Soap
# 1  SO-100775  2026-05-24       Danny Arnold     San Miguel  Instant Noodles
# 2  SO-100791  2026-05-24  Robert Richardson          Rizal  Instant Noodles
# 3  SO-100131  2026-05-24     Jason Gonzalez  Bagong Silang  Canned Sardines
# 4  SO-100464  2026-05-24    Colleen Stewart       San Jose             Rice
#
#     category  quantity  unit_price  total_amount payment_method
# 0   Beverage       3.0      281.92        845.76           Cash
# 1    Grocery       3.0      447.94       1343.82          GCash
# 2   Beverage       5.0      523.34       2616.70           Card
# 3  Household       5.0      573.32       2866.60  Bank Transfer
# 4  Household       2.0      738.04       1476.08           Card
# Shape: (1020, 10)
#
# === school_enrollment.csv ===
#    student_id    student_name  birth_date grade_level  \
# 0  STU-300383    Leah Hensley  2018-04-11     Grade 9
# 1  STU-300775  Tristan Molina  2017-11-29     Grade 2
# 2  STU-300791  Dennis Griffin  2016-04-22     Grade 9
# 3  STU-300131     Anna Howard  2011-01-21     Grade 8
# 4  STU-300464    Travis Lucas  2007-09-13     Grade 7
#
#                     school_name   barangay  math_score  english_score  \
# 0       Rizal Elementary School  Sta. Cruz        72.0           86.0
# 1  San Isidro Elementary School  Magsaysay        64.0           77.0
# 2      Mabini Integrated School      Rizal        68.0           98.0
# 3      Mabini Integrated School  Bayanihan        55.0           83.0
# 4  San Isidro Elementary School   San Jose        82.0           97.0
#
#    science_score  attendance_rate
# 0           83.0             0.88
# 1           50.0             0.95
# 2           79.0             0.95
# 3           65.0             0.81
# 4           90.0             0.95
# Shape: (1020, 10)

# %% [markdown]
# ## What this creates
# The four generated CSV files are stored in `data/generated/` and can be used by the rest of the notebooks.
