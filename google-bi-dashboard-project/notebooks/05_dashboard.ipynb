# %%
# Preview the exported HTML within the notebook (iframe)
if Path('dashboards/dashboard.html').exists():
    display(IFrame('dashboards/dashboard.html', width=1200, height=800))
else:
    print('dashboards/dashboard.html not found — run the previous cell to create it')

# %%
# Build and export dashboard HTML
out_html = 'dashboards/dashboard.html'
Path('dashboards').mkdir(exist_ok=True)
dashboard.build_sample_dashboard(paths=paths, out_html=out_html)
print('Dashboard written to', out_html)

# %%
# Paths to cleaned (or generated) data
base = Path('data/generated')
paths = {
    'sales': str(base/'sales_orders.csv'),
    'barangay': str(base/'barangay_census.csv'),
    'medical': str(base/'medical_records.csv'),
    'enrollment': str(base/'school_enrollment.csv')
}
paths

# %%
# Imports
from pathlib import Path
import src.dashboard as dashboard
import pandas as pd
from IPython.display import IFrame
print('imports ok')

# %% [markdown]
# ## Install/Verify
# Ensure dependencies are installed: `pip install -r requirements.txt`

# %% [markdown]
# # 05_dashboard.ipynb
# This notebook builds an interactive Plotly dashboard using `src/dashboard.build_sample_dashboard` and exports `dashboards/dashboard.html`. Run these cells after generating and cleaning the datasets.
