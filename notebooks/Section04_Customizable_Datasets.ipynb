# %% [markdown]
# # **Run instructions:** This notebook uses `data/section4_datasets.csv`. Run cells to see aggregations and plots.
#
# Tip: change column names in the code to match your CSV if using your own data.
