# %% [markdown]
# # **Run instructions:** This notebook uses `data/section3_tools.csv` — open the table and try small demos.
#
# Tip: explore each tool's docs link in Section 9 for setup instructions.
