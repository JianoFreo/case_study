# %% [markdown]
# # **Run instructions:** Run each cell in order. This notebook uses `data/section2_principles.csv`.
#
# Tip: use `%matplotlib inline` or run in Jupyter to view matplotlib/seaborn charts.
