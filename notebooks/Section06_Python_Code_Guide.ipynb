# %% [markdown]
# # **Run instructions:** This notebook uses `data/section6_codeguide.csv` and demonstrates pandas time-series operations.
#
# Tip: ensure `pandas` and `plotly` are installed (see requirements.txt).
