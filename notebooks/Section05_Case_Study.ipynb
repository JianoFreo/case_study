# %% [markdown]
# # **Run instructions:** This notebook uses `data/section5_case_study.csv`. Run cells to generate the case study charts.
#
# Tip: change chart colors and titles to match your business question.
