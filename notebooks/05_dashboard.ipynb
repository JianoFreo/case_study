# %% [markdown]
# # 05_dashboard.ipynb
# Build a professional interactive dashboard and export it to HTML. The notebook ensures its own data and dependencies.

# %%
from pathlib import Path
import sys
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from faker import Faker
warnings.filterwarnings('ignore')
BASE_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
RAW_DATA_DIR = BASE_DIR / 'data' / 'raw'
PROCESSED_DATA_DIR = BASE_DIR / 'data' / 'processed'
GENERATED_DATA_DIR = BASE_DIR / 'data' / 'generated'
RAW_DATA_DIR.mkdir(parents=True, exist_ok=True)
PROCESSED_DATA_DIR.mkdir(parents=True, exist_ok=True)
GENERATED_DATA_DIR.mkdir(parents=True, exist_ok=True)
if str(BASE_DIR) not in sys.path:
    sys.path.insert(0, str(BASE_DIR))
import src.generate_data as generate_data
import src.dashboard as dashboard
print('Setup complete')
# Out:
# Setup complete

# %% [markdown]
# ## Setup Environment and Imports
# Import visualization libraries and data tools, then configure directory paths. This sets up everything needed to build and export the interactive dashboard.

# %%
# Ensure data exists and build the file paths dictionary
if not (GENERATED_DATA_DIR / 'sales_orders.csv').exists():
    generate_data.generate_all(n_each=1000, out_dir=GENERATED_DATA_DIR)
paths = {
    'sales': str(GENERATED_DATA_DIR / 'sales_orders.csv'),
    'barangay': str(GENERATED_DATA_DIR / 'barangay_census.csv'),
    'medical': str(GENERATED_DATA_DIR / 'medical_records.csv'),
    'enrollment': str(GENERATED_DATA_DIR / 'school_enrollment.csv'),
}
paths
# Out:
# {'sales': 'c:\\Users\\User\\Desktop\\case_study\\data\\generated\\sales_orders.csv',
#  'barangay': 'c:\\Users\\User\\Desktop\\case_study\\data\\generated\\barangay_census.csv',
#  'medical': 'c:\\Users\\User\\Desktop\\case_study\\data\\generated\\medical_records.csv',
#  'enrollment': 'c:\\Users\\User\\Desktop\\case_study\\data\\generated\\school_enrollment.csv'}

# %% [markdown]
# ## Ensure Data and Build File Paths
# Verify that all datasets exist, creating them if necessary. Build a dictionary mapping dataset names to file paths for dashboard construction.

# %%
# Create dashboard HTML
out_html = BASE_DIR / 'dashboards' / 'dashboard.html'
dashboard_path = dashboard.build_sample_dashboard(paths, out_html)
dashboard_path
# Out:
# 'c:\\Users\\User\\Desktop\\case_study\\dashboards\\dashboard.html'

# %% [markdown]
# ## Build and Export Dashboard to HTML
# Create the complete interactive dashboard using the dashboard module. The HTML file is saved to `dashboards/dashboard.html` for sharing with stakeholders.

# %%
# Preview key KPI values used for the dashboard
sales = pd.read_csv(paths['sales'])
sales['total_amount'] = pd.to_numeric(sales['total_amount'], errors='coerce')
kpis = {
    'total_revenue': float(sales['total_amount'].fillna(0).sum()),
    'orders_count': int(len(sales)),
    'avg_order_value': float(sales['total_amount'].fillna(0).mean())
}
kpis
# Out:
# {'total_revenue': 1970178.12,
#  'orders_count': 1020,
#  'avg_order_value': 1931.5471764705883}

# %% [markdown]
# ## Calculate and Display Key KPIs
# Compute the main performance indicators (total revenue, order count, average order value) that serve as the dashboard headlines. These metrics summarize overall business health.

# %% [markdown]
# ## Visualizations
# Create the following charts: Revenue by Barangay, Monthly Revenue Trend, Payment Method Mix, Order Quantity vs Revenue.

# %%
# Import the visualization helpers
from src.visualization import (
    revenue_by_barangay,
    monthly_revenue_trend,
    payment_method_mix,
    order_qty_vs_revenue,
)
# Ensure `sales` dataframe is available
try:
    sales
except NameError:
    sales = pd.read_csv(paths['sales'])
    sales['total_amount'] = pd.to_numeric(sales['total_amount'], errors='coerce')

# 1) Revenue by Barangay
fig1 = revenue_by_barangay(sales, barangay_col='barangay', revenue_col='total_amount', top_n=10)
fig1.show()

# 2) Monthly Revenue Trend
fig2 = monthly_revenue_trend(sales, date_col='order_date', revenue_col='total_amount', freq='M')
fig2.show()

# 3) Payment Method Mix
fig3 = payment_method_mix(sales, payment_col='payment_method')
fig3.show()

# 4) Order Quantity vs Revenue
fig4 = order_qty_vs_revenue(sales, qty_col='quantity', revenue_col='total_amount')
fig4.show()

# %% [markdown]
# ## Dashboard export
# The HTML export is written to `dashboards/dashboard.html`.
