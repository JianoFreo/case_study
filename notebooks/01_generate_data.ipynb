# %% [markdown]
# # 01_generate_data.ipynb
# Generate realistic synthetic Philippine-style datasets for the BI project. This notebook can run independently from top to bottom.

# %%
from pathlib import Path
import sys
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from faker import Faker
warnings.filterwarnings('ignore')
BASE_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
RAW_DATA_DIR = BASE_DIR / 'data' / 'raw'
PROCESSED_DATA_DIR = BASE_DIR / 'data' / 'processed'
GENERATED_DATA_DIR = BASE_DIR / 'data' / 'generated'
RAW_DATA_DIR.mkdir(parents=True, exist_ok=True)
PROCESSED_DATA_DIR.mkdir(parents=True, exist_ok=True)
GENERATED_DATA_DIR.mkdir(parents=True, exist_ok=True)
if str(BASE_DIR) not in sys.path:
    sys.path.insert(0, str(BASE_DIR))
import src.generate_data as generate_data
print('Setup complete')
# Out:
# Setup complete

# %% [markdown]
# ## Setup Dependencies and Paths
# This cell imports all required libraries (pandas, numpy, plotly, faker) and sets up directory paths for storing generated data. It ensures all necessary folders exist so the notebook can run end-to-end.

# %%
# Generate all datasets if they do not already exist
generated_paths = generate_data.generate_all(n_each=1000, out_dir=GENERATED_DATA_DIR)
generated_paths
# Out:
# {'barangay_census.csv': 'c:\\Users\\User\\Desktop\\case_study\\data\\generated\\barangay_census.csv',
#  'sales_orders.csv': 'c:\\Users\\User\\Desktop\\case_study\\data\\generated\\sales_orders.csv',
#  'medical_records.csv': 'c:\\Users\\User\\Desktop\\case_study\\data\\generated\\medical_records.csv',
#  'school_enrollment.csv': 'c:\\Users\\User\\Desktop\\case_study\\data\\generated\\school_enrollment.csv'}

# %% [markdown]
# ## Generate Synthetic Datasets
# This cell creates four realistic synthetic datasets with 1,000 records each: sales orders, barangay census, medical records, and school enrollment. These mirror real-world business data patterns.

# %%
# List generated files
csv_files = sorted(GENERATED_DATA_DIR.glob('*.csv'))
[p.name for p in csv_files]
# Out:
# ['barangay_census.csv',
#  'medical_records.csv',
#  'sales_orders.csv',
#  'school_enrollment.csv']

# %% [markdown]
# ## List Generated Files
# This cell shows what CSV files were created and saved to the `data/generated/` directory for use in subsequent analysis notebooks.

# %%
# Preview the first few rows of each dataset
for csv_path in csv_files:
    print(f'\n=== {csv_path.name} ===')
    preview_df = pd.read_csv(csv_path)
    display(preview_df.head())
    print('Shape:', preview_df.shape)
# Out:
# === barangay_census.csv ===
#    record_id       barangay          city  households  population  \
# 0        384      Bayanihan  Bacolod City       190.0       570.0
# 1        776  Bagong Silang    Davao City       192.0       768.0
# 2        792       San Jose   Quezon City       194.0       776.0
# 3        132      Bayanihan   Iloilo City       179.0       895.0
# 4        465     San Isidro         Pasig       218.0      1090.0
#
#    median_income collection_date
# 0        25989.0      2026-02-06
# 1        19328.0      2026-02-27
# 2        23684.0      2025-06-16
# 3        10826.0      2024-11-01
# 4        20264.0      2025-08-05
# Shape: (1020, 7)
#
# === medical_records.csv ===
#      visit_id  visit_date     patient_name   age     sex       barangay  \
# 0  MED-200383  2025-06-25   Keith Campbell  41.0  Female  Bagong Silang
# 1  MED-200775  2026-01-17   David Williams  26.0    Male      Bayanihan
# ...

# %% [markdown]
# ## Preview Each Dataset
# This cell displays a sample of the first few rows from each generated dataset along with its dimensions. This gives a quick overview of the data structure and content.

# %% [markdown]
# ## What this creates
# The four generated CSV files are stored in `data/generated/` and can be used by the rest of the notebooks.
