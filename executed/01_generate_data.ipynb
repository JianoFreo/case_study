# %% [markdown]
# # 01_generate_data.ipynb
# Generate realistic synthetic Philippine-style datasets for the BI project. This notebook can run independently from top to bottom.

# %%
from pathlib import Path
import sys
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from faker import Faker
warnings.filterwarnings('ignore')
BASE_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
RAW_DATA_DIR = BASE_DIR / 'data' / 'raw'
PROCESSED_DATA_DIR = BASE_DIR / 'data' / 'processed'
GENERATED_DATA_DIR = BASE_DIR / 'data' / 'generated'
RAW_DATA_DIR.mkdir(parents=True, exist_ok=True)
PROCESSED_DATA_DIR.mkdir(parents=True, exist_ok=True)
GENERATED_DATA_DIR.mkdir(parents=True, exist_ok=True)
if str(BASE_DIR) not in sys.path:
    sys.path.insert(0, str(BASE_DIR))
import src.generate_data as generate_data
import src.cleaning as cleaning
print('Setup complete')
# Out:
# Setup complete

# %%
# Generate all datasets if they do not already exist
generated_paths = generate_data.generate_all(n_each=1000, out_dir=GENERATED_DATA_DIR)
generated_paths
# Out:
# {'barangay_census.csv': 'c:\\Users\\User\\Desktop\\case_study\\google-bi-dashboard-project\\executed\\data\\generated\\barangay_census.csv',
#  'sales_orders.csv': 'c:\\Users\\User\\Desktop\\case_study\\google-bi-dashboard-project\\executed\\data\\generated\\sales_orders.csv',
#  'medical_records.csv': 'c:\\Users\\User\\Desktop\\case_study\\google-bi-dashboard-project\\executed\\data\\generated\\medical_records.csv',
#  'school_enrollment.csv': 'c:\\Users\\User\\Desktop\\case_study\\google-bi-dashboard-project\\executed\\data\\generated\\school_enrollment.csv'}

# %%
# List generated files
csv_files = sorted(GENERATED_DATA_DIR.glob('*.csv'))
[p.name for p in csv_files]
# Out:
# ['barangay_census.csv',
#  'medical_records.csv',
#  'sales_orders.csv',
#  'school_enrollment.csv']

# %%
# Preview the first few rows of each dataset
for csv_path in csv_files:
    print(f'\n=== {csv_path.name} ===')
    preview_df = pd.read_csv(csv_path)
    display(preview_df.head())
    print('Shape:', preview_df.shape)
# Out:
# === barangay_census.csv ===
#    record_id   barangay          city  households  population  median_income  \
# 0        384      Rizal    Davao City       177.0       885.0        28656.0
# 1        776   Maligaya     Cebu City       202.0      1010.0        16365.0
# 2        792  Sta. Cruz  Bacolod City       211.0      1055.0        12689.0
# 3        132  Poblacion    Davao City       234.0      1170.0        18271.0
# 4        465  Sta. Cruz         Pasig       222.0      1110.0        19486.0
#
#   collection_date
# 0      2024-11-05
# 1      2025-04-04
# 2      2025-02-11
# 3      2024-08-19
# 4      2025-06-26
# Shape: (1020, 7)
#
# === medical_records.csv ===
#      visit_id  visit_date       patient_name   age     sex   barangay  \
# 0  MED-200383  2025-06-06    Andrew Marshall  62.0  Female  Del Pilar
# 1  MED-200775  2025-02-23  Mr. Brian Navarro  41.0    Male     Mabini
# 2  MED-200791  2024-07-06   Lawrence Fuentes  49.0  Female     Mabini
# ...

# %% [markdown]
# ## What this creates
# The four generated CSV files are stored in `data/generated/` and can be used by the rest of the notebooks.
